# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\mohan\Downloads\OnlineRetail (2).csv",encoding='latin')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.replace(["?", "NA", "--", "-1", "9999"], np.nan, inplace=True) ## incase null represented as these values

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1501
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['StockCode'].nunique()
# Out:
# 4070

# %%
df['CustomerID'].nunique()
# Out:
# 4372

# %%
df['Description'].nunique()
# Out:
# 4222

# %%
df.groupby('StockCode')['Description'].nunique().sort_values(ascending=False).head(10)
# Out:
# StockCode
# 20713     8
# 23084     7
# 85175     6
# 85172     5
# 72807A    5
# 23343     5
# 21181     5
# 21830     5
# 35965     4
# 46000S    4
# Name: Description, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])

# %%
df['InvoiceDate'] = df['InvoiceDate'].dt.date

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01       2.55     17850.0  United Kingdom
# 1  2010-12-01       3.39     17850.0  United Kingdom
# 2  2010-12-01       2.75     17850.0  United Kingdom
# 3  2010-12-01       3.39     17850.0  United Kingdom
# 4  2010-12-01       3.39     17850.0  United Kingdom

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#        'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %%
df[df['Country']=='United Kingdom']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False)
##united kingdom contibutes the most
# Out:
# Country
# United Kingdom          3950
# Germany                   95
# France                    87
# Spain                     31
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     15
# Finland                   12
# Austria                   11
# Norway                    10
# Australia                  9
# Denmark                    9
# Netherlands                9
# Channel Islands            9
# Japan                      8
# Sweden                     8
# Cyprus                     8
# Poland                     6
# Unspecified                4
# USA                        4
# Canada                     4
# Israel                     4
# Greece                     4
# EIRE                       3
# United Arab Emirates       2
# Bahrain                    2
# Malta                      2
# Brazil                     1
# Lebanon                    1
# Iceland                    1
# ...

# %%
df['TotalAmount'] = df['Quantity'] * df['UnitPrice']
df.groupby('Country')['TotalAmount'].sum().sort_values(ascending=False)
## revenue per country
# Out:
# Country
# United Kingdom          6767873.394
# Netherlands              284661.540
# EIRE                     250285.220
# Germany                  221698.210
# France                   196712.840
# Australia                137077.270
# Switzerland               55739.400
# Spain                     54774.580
# Belgium                   40910.960
# Sweden                    36595.910
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  29059.810
# Finland                   22326.740
# Channel Islands           20086.290
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12946.290
# Austria                   10154.320
# Singapore                  9120.390
# Poland                     7213.140
# Israel                     6994.250
# Greece                     4710.520
# Iceland                    4310.000
# Canada                     3666.380
# Unspecified                2667.070
# ...

# %%
df.groupby(['Country','StockCode'])['Quantity'].sum().sort_values(ascending=False).head()
## top products per country
# Out:
# Country         StockCode
# United Kingdom  84077        47982
#                 22197        45217
#                 85099B       40880
#                 84879        32679
#                 85123A       32154
# Name: Quantity, dtype: int64

# %%
## number of times cust ordered
df.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 14911.0    248
# 12748.0    224
# 17841.0    169
# 14606.0    128
# 15311.0    118
#           ...
# 18240.0      1
# 12378.0      1
# 18262.0      1
# 12361.0      1
# 12357.0      1
# Name: InvoiceNo, Length: 4372, dtype: int64

# %%
# total order by cust
df.groupby('CustomerID')['Quantity'].sum().sort_values(ascending=False)
# Out:
# CustomerID
# 14646.0    196719
# 12415.0     77242
# 14911.0     77180
# 17450.0     69029
# 18102.0     64122
#             ...
# 16252.0      -158
# 16742.0      -189
# 14213.0      -244
# 15823.0      -283
# 16546.0      -303
# Name: Quantity, Length: 4372, dtype: int64

# %%
df.groupby('CustomerID')['TotalAmount'].sum().sort_values(ascending=False)
## to know who spend the most
# Out:
# CustomerID
# 14646.0    279489.02
# 18102.0    256438.49
# 17450.0    187482.17
# 14911.0    132572.62
# 12415.0    123725.45
#              ...
# 12503.0     -1126.00
# 17603.0     -1165.30
# 14213.0     -1192.20
# 15369.0     -1592.49
# 17448.0     -4287.63
# Name: TotalAmount, Length: 4372, dtype: float64

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount
# 0  2010-12-01       2.55     17850.0  United Kingdom        15.30
# 1  2010-12-01       3.39     17850.0  United Kingdom        20.34
# 2  2010-12-01       2.75     17850.0  United Kingdom        22.00
# 3  2010-12-01       3.39     17850.0  United Kingdom        20.34
# 4  2010-12-01       3.39     17850.0  United Kingdom        20.34

# %%
df[df['Quantity']<=0]## to know if there is any returns or not
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#        InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount
# ...

# %%
## as we found the return we have to remove those as well before making the rfe

df = df[df['Quantity'] > 0]

# %% [raw]
# ## for segmentation i wil be doing rfm
# r=recency  -how recently a customer made their last purchase
#            -cust who bought recently are more likely to buy again
# f=frequency -- how often customer makes the purchases
#              - loyal customers orders more than one time
# m= monetary  --how much money a customer has spend in total
#               - hign value customers contribute more revenue

# %% [raw]
# why i did this -- for segmentation, cutshort the big data but in meaningful way

# %%
snapshot_date = df['InvoiceDate'].max() + pd.Timedelta(days=1)

rfm = df.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days,  # Recency
    'InvoiceNo': 'nunique',                                  # Frequency
    'TotalAmount': 'sum'                                     # Monetary
}).rename(columns={'InvoiceDate':'Recency',
                   'InvoiceNo':'Frequency',
                   'TotalAmount':'Monetary'})

# %%
rfm
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0           3          7   4310.00
# 12348.0          76          4   1797.24
# 12349.0          19          1   1757.55
# 12350.0         311          1    334.40
# ...             ...        ...       ...
# 18280.0         278          1    180.60
# 18281.0         181          1     80.82
# 18282.0           8          2    178.05
# 18283.0           4         16   2094.88
# 18287.0          43          3   1837.28
#
# [4339 rows x 3 columns]

# %%
customer_country = df.groupby('CustomerID')['Country'].agg(lambda x: x.value_counts().index[0])
rfm = rfm.merge(customer_country, on='CustomerID')

# %%
rfm[rfm['Country']=='United Kingdom']
# Out:
#             Recency  Frequency  Monetary         Country
# CustomerID
# 12346.0         326          1  77183.60  United Kingdom
# 12747.0           3         11   4196.01  United Kingdom
# 12748.0           1        210  33719.73  United Kingdom
# 12749.0           4          5   4090.88  United Kingdom
# 12820.0           4          4    942.34  United Kingdom
# ...             ...        ...       ...             ...
# 18280.0         278          1    180.60  United Kingdom
# 18281.0         181          1     80.82  United Kingdom
# 18282.0           8          2    178.05  United Kingdom
# 18283.0           4         16   2094.88  United Kingdom
# 18287.0          43          3   1837.28  United Kingdom
#
# [3921 rows x 4 columns]

# %%
rfm.describe()
# Out:
#            Recency    Frequency       Monetary
# count  4339.000000  4339.000000    4339.000000
# mean     93.041484     4.271952    2053.793018
# std     100.007757     7.705493    8988.248381
# min       1.000000     1.000000       0.000000
# 25%      18.000000     1.000000     307.245000
# 50%      51.000000     2.000000     674.450000
# 75%     142.500000     5.000000    1661.640000
# max     374.000000   210.000000  280206.020000

# %%
rfm['Recency'].hist(bins=50)
# Out:
# <Axes: >

# %%
rfm['Frequency'].hist(bins=50)
# Out:
# <Axes: >

# %%
rfm['Monetary'].hist(bins=50)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm[['Recency','Frequency','Monetary']])

# %%
from sklearn.cluster import KMeans

inertia = []
K = range(2, 11)  

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
plt.plot(K, inertia, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(rfm_scaled)
    score = silhouette_score(rfm_scaled, labels)
    silhouette_scores.append(score)

plt.plot(K, silhouette_scores, 'ro-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method for Optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)

rfm['Cluster'] = kmeans.fit_predict(rfm_scaled)

# %%
rfm
# Out:
#             Recency  Frequency  Monetary         Country  Cluster
# CustomerID
# 12346.0         326          1  77183.60  United Kingdom        3
# 12347.0           3          7   4310.00         Iceland        0
# 12348.0          76          4   1797.24         Finland        0
# 12349.0          19          1   1757.55           Italy        0
# 12350.0         311          1    334.40          Norway        1
# ...             ...        ...       ...             ...      ...
# 18280.0         278          1    180.60  United Kingdom        1
# 18281.0         181          1     80.82  United Kingdom        1
# 18282.0           8          2    178.05  United Kingdom        0
# 18283.0           4         16   2094.88  United Kingdom        3
# 18287.0          43          3   1837.28  United Kingdom        0
#
# [4339 rows x 5 columns]

# %%
plt.figure(figsize=(8,6))
plt.scatter(rfm['Frequency'], rfm['Monetary'], 
            c=rfm['Cluster'], cmap='viridis', alpha=0.6)

plt.xlabel('Frequency (Number of Orders)')
plt.ylabel('Monetary (Total Spend)')
plt.title('Customer Segments based on RFM Clustering')
plt.colorbar(label='Cluster')
plt.show()

# %%
rfm
# Out:
#             Recency  Frequency  Monetary         Country  Cluster
# CustomerID
# 12346.0         326          1  77183.60  United Kingdom        3
# 12347.0           3          7   4310.00         Iceland        0
# 12348.0          76          4   1797.24         Finland        0
# 12349.0          19          1   1757.55           Italy        0
# 12350.0         311          1    334.40          Norway        1
# ...             ...        ...       ...             ...      ...
# 18280.0         278          1    180.60  United Kingdom        1
# 18281.0         181          1     80.82  United Kingdom        1
# 18282.0           8          2    178.05  United Kingdom        0
# 18283.0           4         16   2094.88  United Kingdom        3
# 18287.0          43          3   1837.28  United Kingdom        0
#
# [4339 rows x 5 columns]

# %%
rfm.groupby('Cluster')[['Recency','Frequency','Monetary']].mean()
# Out:
#             Recency  Frequency       Monetary
# Cluster
# 0         44.477079   3.655206    1349.382627
# 1        249.173421   1.551367     478.194732
# 2          7.615385  82.692308  127338.313846
# 3         16.123223  22.047393   12453.225924

# %% [raw]
# cluster 2--
#            those can be considered vips
#             --they are the biggest revenue drivers
#
# cluster 3 - loyal customers
#               --they are consistent buyers
#
# cluster 0 -- they buy things occasionally
#            -- target with promotions  to increase frequency
#              -- can reach cluster 0  if done well
#
# cluster 1 ---  not often /at risk
#          ---need to do something before they churn
